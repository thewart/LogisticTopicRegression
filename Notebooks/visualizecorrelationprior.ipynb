# %%
using Distributions, Gadfly

# %%
τ = rand(InverseGamma(3,1),10000);

# %%
ρ = τ./(τ+1);
plot(x=ρ,Geom.histogram(bincount=50))
# Out:
# Plot(...)

# %%
plot(x=τ,Geom.histogram)
# Out:
# Plot(...)
