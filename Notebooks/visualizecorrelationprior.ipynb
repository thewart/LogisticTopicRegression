# %%
using Distributions, Gadfly

# %%
ν0 = 1.0;
σ20 = 0.25;
τ = rand(InverseGamma(ν0/2,σ20*ν0/2),10000);

# %%
ρ = τ./(τ+1);
plot(x=ρ,Geom.histogram(bincount=25))
# Out:
# Plot(...)

# %%
plot(x=τ,Geom.histogram)
# Out:
# Plot(...)
