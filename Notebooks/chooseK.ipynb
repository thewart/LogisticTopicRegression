# %%
using RCall, DataFrames 
addprocs(6);
using LogTopReg
import Lazy.@>, Lazy.@>>
# Out:
# WARNING: Method definition describe(AbstractArray) in module StatsBase at /home/seth/.julia/v0.5/StatsBase/src/scalarstats.jl:573 overwritten in module DataFrames at /home/seth/.julia/v0.5/DataFrames/src/abstractdataframe/abstractdataframe.jl:407.
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# data.table 1.10.4
#   The fastest way to learn (by data.table authors): https://www.datacamp.com/courses/data-analysis-the-data-table-way
#   Documentation: ?data.table, example(data.table) and browseVignettes("data.table")
#   Release notes, videos and slides: http://r-datatable.com
#
# Attaching package: ‘data.table’
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last

# %%
include("../juliafromR.jl");
Y,X,pss0 = getfocaldata();
# Out:
# WARNING: RCall.jl: Warning in fread(files[i]) :
#   Bumped column 5 to type character on data row 6913, field contains '208B0'. Coercing previously read values in this column from logical, integer or numeric back to character which may not be lossless; e.g., if '00' and '000' occurred before they will now be just '0', and there may be inconsistencies with treatment of ',,' and ',NA,' too (if they occurred in this column before the bump). If this matters please rerun and set 'colClasses' to 'character' for this column. Please note that column type detection uses a sample of 1,000 rows (100 rows at 10 points) so hopefully this message should be very rare. If reporting to datatable-help, please rerun and include the output from verbose=TRUE.
# Warning in fread(files[i]) :
#   Bumped column 15 to type character on data row 57995, field contains 'sister'. Coercing previously read values in this column from logical, integer or numeric back to character which may not be lossless; e.g., if '00' and '000' occurred before they will now be just '0', and there may be inconsistencies with treatment of ',,' and ',NA,' too (if they occurred in this column before the bump). If this matters please rerun and set 'colClasses' to 'character' for this column. Please note that column type detection uses a sample of 1,000 rows (100 rows at 10 points) so hopefully this message should be very rare. If reporting to datatable-help, please rerun and include the output from verbose=TRUE.
# Warning in melt.data.table(sdat) :
#   To be consistent with reshape2's melt, id.vars and measure.vars are internally guessed when both are 'NULL'. All non-numeric/integer/logical type columns are conisdered id.vars, which in this case are columns [Observation, behavior]. Consider providing at least one of 'id' or 'measure' vars in future.
# Warning in melt.data.table(sdat) :
#   To be consistent with reshape2's melt, id.vars and measure.vars are internally guessed when both are 'NULL'. All non-numeric/integer/logical type columns are conisdered id.vars, which in this case are columns [Observation, behavior]. Consider providing at least one of 'id' or 'measure' vars in future.
# Warning in melt.data.table(sdat) :
#   To be consistent with reshape2's melt, id.vars and measure.vars are internally guessed when both are 'NULL'. All non-numeric/integer/logical type columns are conisdered id.vars, which in this case are columns [Observation, behavior]. Consider providing at least one of 'id' or 'measure' vars in future.
# Using 'V1' as value column. Use 'value.var' to override
# Loading required package: xlsx
# Loading required package: rJava
# Loading required package: xlsxjars
# WARNING:     `rcopy(str::AbstractString)` is deprecated, use `rcopy(reval(str))`
#     or rcopy(R"<your code>") instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in rcopy at /home/seth/.julia/v0.5/RCall/src/deprecated.jl:2 [inlined]
#  in getfocaldata() at /home/seth/code/LogisticTopicRegression/juliafromR.jl:3
#  in include_string(::String, ::String) at ./loading.jl:441
#  in execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/seth/.julia/v0.5/IJulia/src/execute_request.jl:156
#  in eventloop(::ZMQ.Socket) at /home/seth/.julia/v0.5/IJulia/src/eventloop.jl:8
#  in (::IJulia.##13#19)() at ./task.jl:360
# while loading In[2], in expression starting on line 2

# %%
K = [5,10,15,20];
@time fit = @parallel (vcat) for k in K
    topiclmm(Y,X,pss0,k,1000,1);
end;
lp = pmap(lppd,fit,fill(Y,length(K)));
# Out:
# 211.858357 seconds (8.88 M allocations: 559.260 MB, 0.28% gc time)

# %%
ns = length(fit[1][:τ]);
lpdat = DataFrame(loglik=vcat(map(y -> sum(hcat(y...),2),lp)...)[:],chain=repeat(map(string,1:length(K)),inner=[ns]),
iter=repeat(collect(1:ns),outer=[length(K)]),K=repeat(K,inner=[ns]));

# %%
using Gadfly
plot(lpdat[(lpdat[:iter].>100),:],y="loglik",x="iter",color="K",Geom.line)
# Out:
# WARNING: Method definition describe(AbstractArray) in module StatsBase at /home/seth/.julia/v0.5/StatsBase/src/scalarstats.jl:573 overwritten in module DataFrames at /home/seth/.julia/v0.5/DataFrames/src/abstractdataframe/abstractdataframe.jl:407.
# WARNING: Method definition describe(AbstractArray) in module StatsBase at /home/seth/.julia/v0.5/StatsBase/src/scalarstats.jl:573 overwritten in module DataFrames at /home/seth/.julia/v0.5/DataFrames/src/abstractdataframe/abstractdataframe.jl:407.
# WARNING: Method definition describe(AbstractArray) in module StatsBase at /home/seth/.julia/v0.5/StatsBase/src/scalarstats.jl:573 overwritten in module DataFrames at /home/seth/.julia/v0.5/DataFrames/src/abstractdataframe/abstractdataframe.jl:407.
# WARNING: Method definition describe(AbstractArray) in module StatsBase at /home/seth/.julia/v0.5/StatsBase/src/scalarstats.jl:573 overwritten in module DataFrames at /home/seth/.julia/v0.5/DataFrames/src/abstractdataframe/abstractdataframe.jl:407.
# WARNING: Method definition describe(AbstractArray) in module StatsBase at /home/seth/.julia/v0.5/StatsBase/src/scalarstats.jl:573 overwritten in module DataFrames at /home/seth/.julia/v0.5/DataFrames/src/abstractdataframe/abstractdataframe.jl:407.
# WARNING: Method definition describe(AbstractArray) in module StatsBase at /home/seth/.julia/v0.5/StatsBase/src/scalarstats.jl:573 overwritten in module DataFrames at /home/seth/.julia/v0.5/DataFrames/src/abstractdataframe/abstractdataframe.jl:407.
# Plot(...)

# %%
warmup = 100;
loo = Vector{Dict{Symbol,Any}}(length(K))
rcopy(reval("library(loo)"));
for i in 1:length(K)
    globalEnv[:lp] = hcat(lp[i]...)[(warmup+1):ns,:];
    loo[i] = rcopy(reval("loo(lp)"));
end
# Out:
# WARNING: RCall.jl: Warning: Some Pareto k diagnostic values are too high. See help('pareto-k-diagnostic') for details.
# WARNING: RCall.jl: Warning: Some Pareto k diagnostic values are too high. See help('pareto-k-diagnostic') for details.
# WARNING: RCall.jl: Warning: Some Pareto k diagnostic values are too high. See help('pareto-k-diagnostic') for details.

# %%
plot(y=[loo[i][:looic] for i=1:length(K)],x=map(string,K),Geom.point)
# Out:
# Plot(...)
